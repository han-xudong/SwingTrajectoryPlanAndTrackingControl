# %%
from matplotlib import pyplot as plt
import numpy as np

# Load data
foot_path = np.loadtxt('foot_path.txt', delimiter=',')
foot_opt_path = np.loadtxt('foot_opt_path.txt', delimiter=',')
foot_real_path = np.loadtxt('foot_real_path.txt', delimiter=',')

# Plot
plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(foot_path[:, 0], foot_path[:, 1], foot_path[:, 2], 'b')
num = 500
ax.plot3D(foot_opt_path[:num, 0], foot_opt_path[:num, 1], foot_opt_path[:num, 2], 'r')
print(foot_opt_path[num - 1, :])
print(foot_opt_path[num - 2, :])
print(foot_path[num - 1, :])
print(foot_path[num - 2, :])
# ax.plot3D(foot_real_path[:, 0], foot_real_path[:, 1], foot_real_path[:, 2], 'g')
# Out:
# [ 0.22320593 -0.16       -0.25667324]
# [ 0.22222509 -0.16       -0.25615409]
# [ 0.2994     -0.16       -0.30944112]
# [ 0.2988     -0.16       -0.30888448]
